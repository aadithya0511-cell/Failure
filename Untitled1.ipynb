# %% [markdown]
# <a href="https://colab.research.google.com/github/aadithya0511-cell/Failure/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create index.html
html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>My Community</title>
    <link rel="stylesheet" href="style.css">
</head>
<body>
    <header>
        <h1>My Community</h1>
    </header>

    <main>
        <section id="public-wall">
            <h2>Public Wall</h2>
            <div id="messages"></div>
            <input type="text" id="message-input" placeholder="Write something...">
            <button id="send-button">Send</button>
            <button id="voice-button">🎤 Speak</button>
        </section>

        <section id="private-chat">
            <h2>Private Chat</h2>
            <div id="private-messages"></div>
            <input type="text" id="private-input" placeholder="Write to friend...">
            <button id="private-send">Send</button>
        </section>

        <section id="uploads">
            <h2>Upload Files</h2>
            <input type="file" id="file-upload">
            <button id="upload-button">Upload</button>
        </section>
    </main>

    <footer>
        <p>My Community © 2025</p>
    </footer>

    <script src="script.js"></script>
</body>
</html>
"""

with open("index.html", "w") as f:
    f.write(html_code)

print("index.html created!")

# %%
# Create index.html
html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>My Community</title>
    <link rel="stylesheet" href="style.css">
</head>
<body>
    <header>
        <h1>My Community</h1>
    </header>

    <main>
        <section id="public-wall">
            <h2>Public Wall</h2>
            <div id="messages"></div>
            <input type="text" id="message-input" placeholder="Write something...">
            <button id="send-button">Send</button>
            <button id="voice-button">🎤 Speak</button>
        </section>

        <section id="private-chat">
            <h2>Private Chat</h2>
            <div id="private-messages"></div>
            <input type="text" id="private-input" placeholder="Write to friend...">
            <button id="private-send">Send</button>
        </section>

        <section id="uploads">
            <h2>Upload Files</h2>
            <input type="file" id="file-upload">
            <button id="upload-button">Upload</button>
        </section>
    </main>

    <footer>
        <p>My Community © 2025</p>
    </footer>

    <script src="script.js"></script>
</body>
</html>
"""

with open("index.html", "w") as f:
    f.write(html_code)

print("index.html created!")
# Out:
# index.html created!

# %%
# Create style.css
css_code = """
body {
    background-color: #121212;
    color: white;
    font-family: Arial, sans-serif;
    margin: 0;
    padding: 0;
}
header, footer {
    text-align: center;
    padding: 15px;
    background-color: #1e1e1e;
}
main {
    display: flex;
    flex-direction: column;
    align-items: center;
    padding: 20px;
}
section {
    width: 90%;
    max-width: 600px;
    border: 1px solid #333;
    padding: 15px;
    border-radius: 10px;
    margin: 15px 0;
    background-color: #1e1e1e;
}
input, button {
    padding: 10px;
    margin: 5px;
    border-radius: 5px;
    border: none;
}
button {
    background-color: #4CAF50;
    color: white;
    cursor: pointer;
}
button:hover {
    background-color: #45a049;
}
#messages, #private-messages {
    height: 150px;
    overflow-y: scroll;
    border: 1px solid #555;
    padding: 10px;
    margin-bottom: 10px;
    background-color: #222;
}
"""

with open("style.css", "w") as f:
    f.write(css_code)

print("style.css created!")
# Out:
# style.css created!

# %%
# Create script.js
js_code = """
const messageInput = document.getElementById("message-input");
const sendButton = document.getElementById("send-button");
const messagesDiv = document.getElementById("messages");

sendButton.addEventListener("click", () => {
    const msg = messageInput.value;
    if (!msg) return;
    const p = document.createElement("p");
    p.textContent = msg;
    messagesDiv.appendChild(p);
    messageInput.value = "";
    messagesDiv.scrollTop = messagesDiv.scrollHeight;
});

// Voice-to-text
const voiceButton = document.getElementById("voice-button");
if ('webkitSpeechRecognition' in window) {
    const recognition = new webkitSpeechRecognition();
    recognition.continuous = false;
    recognition.interimResults = false;

    voiceButton.addEventListener("click", () => {
        recognition.start();
    });

    recognition.onresult = (event) => {
        const transcript = event.results[0][0].transcript;
        messageInput.value = transcript;
    }
} else {
    voiceButton.disabled = true;
    voiceButton.textContent = "🎤 Not supported";
}
"""

with open("script.js", "w") as f:
    f.write(js_code)

print("script.js created!")
# Out:
# script.js created!
